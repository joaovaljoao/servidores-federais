# %%
import pandas as pd

# %%
df = pd.read_csv('201612_Cadastro.csv', sep=';', encoding='latin1')
# Out:
# /tmp/ipykernel_10679/1497694798.py:1: DtypeWarning: Columns (2,5,7,9,34,36,37,38,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('201612_Cadastro.csv', sep=';', encoding='latin1')

# %%
df.columns
# Out:
# Index(['Id_SERVIDOR_PORTAL', 'NOME', 'CPF', 'MATRICULA', 'DESCRICAO_CARGO',
#        'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO',
#        'SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
#        'ATIVIDADE', 'OPCAO_PARCIAL', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
#        'COD_ORG_LOTACAO', 'ORG_LOTACAO', 'COD_ORGSUP_LOTACAO',
#        'ORGSUP_LOTACAO', 'COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
#        'COD_ORG_EXERCICIO', 'ORG_EXERCICIO', 'COD_ORGSUP_EXERCICIO',
#        'ORGSUP_EXERCICIO', 'COD_TIPO_VINCULO', 'TIPO_VINCULO',
#        'SITUACAO_VINCULO', 'DATA_INICIO_AFASTAMENTO',
#        'DATA_TERMINO_AFASTAMENTO', 'REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
#        'DATA_INGRESSO_CARGOFUNCAO', 'DATA_NOMEACAO_CARGOFUNCAO',
#        'DATA_INGRESSO_ORGAO', 'DOCUMENTO_INGRESSO_SERVICOPUBLICO',
#        'DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'DIPLOMA_INGRESSO_CARGOFUNCAO',
#        'DIPLOMA_INGRESSO_ORGAO', 'DIPLOMA_INGRESSO_SERVICOPUBLICO',
# ...

# %%
df = df[((df['COD_ORG_LOTACAO']==26447) | (df['COD_ORG_EXERCICIO']==26447) | (df['COD_UORG_LOTACAO']==26232000000732))]

# %%
df[df['NOME'] == 'POTY RODRIGUES DE LUCENA']
# Out:
#         Id_SERVIDOR_PORTAL                      NOME             CPF  \
# 614741            78025283  POTY RODRIGUES DE LUCENA  ***.931.004-**
# 614742            78025283  POTY RODRIGUES DE LUCENA  ***.931.004-**
#
#        MATRICULA                   DESCRICAO_CARGO CLASSE_CARGO  \
# 614741   015****  PROFESSOR DO MAGISTERIO SUPERIOR            6
# 614742   015****                    Sem informação          NaN
#
#         REFERENCIA_CARGO PADRAO_CARGO  NIVEL_CARGO SIGLA_FUNCAO  ...  \
# 614741               0.0          NaN        604.0           -1  ...
# 614742              -1.0           -1         -1.0           CD  ...
#
#         JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 614741  DEDICACAO EXCLUSIVA                01/03/2013
# 614742  DEDICACAO EXCLUSIVA                01/07/2015
#
#         DATA_NOMEACAO_CARGOFUNCAO DATA_INGRESSO_ORGAO  \
# 614741                        NaN          05/06/2013
# 614742                        NaN          05/06/2013
#
# ...

# %%
df[['COD_TIPO_VINCULO', 'TIPO_VINCULO']]

# %%
df_cargos = df[df['COD_TIPO_VINCULO']==2]

# %%
df_cargos.head(5)

# %%
def filter_csv(folder, file, chunk_size=1000, suffix='_ufob.csv', cod_orgao='26447', cod_uorg='26232000000732'):
    filtered_data = []
    with open(folder + file, 'r', encoding='latin1') as f:
        reader = csv.reader(f, delimiter=';')
        header = next(reader)
        filtered_data.append(header)
        chunk = []

        for i, row in enumerate(reader):
            if row[17] == cod_orgao or str(row[23]) == '26447' or row[15] == cod_uorg:

                    chunk.append(row)
            if (i + 1) % chunk_size == 0:
                filtered_data.extend(chunk)
                chunk = []
        filtered_data.extend(chunk)
    filtred_folder = 'data/filtered'
    create_folder(filtred_folder)
    new_file = os.path.join(filtred_folder,  file.replace('.csv', suffix))
    with open(new_file, 'w', newline='') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerows(filtered_data)
#         os.remove(folder + file)
    return new_file.split('/')[-1]

def create_folder(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created: {folder_path}")

# %%
import csv
import os
filtered = filter_csv('', '201612_Cadastro.csv')

# %%
filtered.to
# Out:
# [['Id_SERVIDOR_PORTAL',
#   'NOME',
#   'CPF',
#   'MATRICULA',
#   'DESCRICAO_CARGO',
#   'CLASSE_CARGO',
#   'REFERENCIA_CARGO',
#   'PADRAO_CARGO',
#   'NIVEL_CARGO',
#   'SIGLA_FUNCAO',
#   'NIVEL_FUNCAO',
#   'FUNCAO',
#   'CODIGO_ATIVIDADE',
#   'ATIVIDADE',
#   'OPCAO_PARCIAL',
#   'COD_UORG_LOTACAO',
#   'UORG_LOTACAO',
#   'COD_ORG_LOTACAO',
#   'ORG_LOTACAO',
#   'COD_ORGSUP_LOTACAO',
#   'ORGSUP_LOTACAO',
#   'COD_UORG_EXERCICIO',
#   'UORG_EXERCICIO',
#   'COD_ORG_EXERCICIO',
#   'ORG_EXERCICIO',
#   'COD_ORGSUP_EXERCICIO',
#   'ORGSUP_EXERCICIO',
#   'COD_TIPO_VINCULO',
#   'TIPO_VINCULO',
#   'SITUACAO_VINCULO',
#   'DATA_INICIO_AFASTAMENTO',
#   'DATA_TERMINO_AFASTAMENTO',
#   'REGIME_JURIDICO',
#   'JORNADA_DE_TRABALHO',
#   'DATA_INGRESSO_CARGOFUNCAO',
#   'DATA_NOMEACAO_CARGOFUNCAO',
#   'DATA_INGRESSO_ORGAO',
#   'DOCUMENTO_INGRESSO_SERVICOPUBLICO',
#   'DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO',
#   'DIPLOMA_INGRESSO_CARGOFUNCAO',
#   'DIPLOMA_INGRESSO_ORGAO',
# ...

# %%
df_cargos = df_cargos[['Id_SERVIDOR_PORTAL', 'NOME', 'DESCRICAO_CARGO',
       'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
       'COD_ORG_LOTACAO', 'ORG_LOTACAO','COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
       'COD_ORG_EXERCICIO', 'ORG_EXERCICIO','SITUACAO_VINCULO','REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
       'DATA_INGRESSO_CARGOFUNCAO',
       'DATA_INGRESSO_ORGAO','DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'ano', 'mes']]

# %%
df_cargos[df['NOME']=='CLAUDIO ALEX DE OLIVEIRA PIRES']
# Out:
# /tmp/ipykernel_10679/1393212702.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cargos[df['NOME']=='CLAUDIO ALEX DE OLIVEIRA PIRES']
#        Id_SERVIDOR_PORTAL                            NOME  \
# 2693             76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 2871             76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 3095             76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 3407             76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 3721             76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# ...                   ...                             ...
# 41160            76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 41775            76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 42389            76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 43002            76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
# 43632            76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
#
#                                 DESCRICAO_CARGO CLASSE_CARGO  \
# ...

# %%
df_funcao = df[df['COD_TIPO_VINCULO']==1]

# %%
df_funcao.columns
# Out:
# Index(['Id_SERVIDOR_PORTAL', 'NOME', 'CPF', 'MATRICULA', 'DESCRICAO_CARGO',
#        'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO',
#        'SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
#        'ATIVIDADE', 'OPCAO_PARCIAL', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
#        'COD_ORG_LOTACAO', 'ORG_LOTACAO', 'COD_ORGSUP_LOTACAO',
#        'ORGSUP_LOTACAO', 'COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
#        'COD_ORG_EXERCICIO', 'ORG_EXERCICIO', 'COD_ORGSUP_EXERCICIO',
#        'ORGSUP_EXERCICIO', 'COD_TIPO_VINCULO', 'TIPO_VINCULO',
#        'SITUACAO_VINCULO', 'DATA_INICIO_AFASTAMENTO',
#        'DATA_TERMINO_AFASTAMENTO', 'REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
#        'DATA_INGRESSO_CARGOFUNCAO', 'DATA_NOMEACAO_CARGOFUNCAO',
#        'DATA_INGRESSO_ORGAO', 'DOCUMENTO_INGRESSO_SERVICOPUBLICO',
#        'DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'DIPLOMA_INGRESSO_CARGOFUNCAO',
#        'DIPLOMA_INGRESSO_ORGAO', 'DIPLOMA_INGRESSO_SERVICOPUBLICO',
# ...

# %%
df_funcao = df_funcao[['Id_SERVIDOR_PORTAL', 'NOME','SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
       'ATIVIDADE', 'OPCAO_PARCIAL','DATA_INGRESSO_CARGOFUNCAO','ano', 'mes']]

# %%
df_funcao[df_funcao['NOME']=='POTY RODRIGUES DE LUCENA']
# Out:
#        Id_SERVIDOR_PORTAL                      NOME SIGLA_FUNCAO  \
# 2022             78025283  POTY RODRIGUES DE LUCENA           CD
# 7124             78025283  POTY RODRIGUES DE LUCENA           CD
# 15325            78025283  POTY RODRIGUES DE LUCENA           CD
#
#        NIVEL_FUNCAO                         FUNCAO  CODIGO_ATIVIDADE  \
# 2022              2  CARGO DE  DIRECAO - CD - IFES              1129
# 7124              2  CARGO DE  DIRECAO - CD - IFES              1129
# 15325             2  CARGO DE  DIRECAO - CD - IFES              1129
#
#                         ATIVIDADE OPCAO_PARCIAL DATA_INGRESSO_CARGOFUNCAO  \
# 2022   PRO REITOR DE PLANEJAMENTO             S                12/09/2013
# 7124   PRO REITOR DE PLANEJAMENTO             S                01/07/2015
# 15325  PRO REITOR DE PLANEJAMENTO             S                01/07/2015
#
#         ano  mes
# 2022   2014    2
# 7124   2015    8
# 15325  2017    2
