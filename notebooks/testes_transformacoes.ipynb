# %%
import pandas as pd

# %%
df = pd.read_csv('concatenated.csv', sep=',')

# %%
df.head()
# Out:
#    Id_SERVIDOR_PORTAL                           NOME             CPF  \
# 0            75714101      ADMA KATIA LACERDA CHAVES  ***.901.765-**
# 1            84412838  ADRIANA MIGLIORINI KIECKHOFER  ***.003.729-**
# 2            80626796             ALEX ALVAREZ SILVA  ***.407.926-**
# 3            74814273  ALEXANDRE EMMANUEL BORTOLETTO  ***.202.949-**
# 4            81706863                   ALINE CRAIDE  ***.189.240-**
#
#   MATRICULA   DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  \
# 0   018****  PROFESSOR 3 GRAU            5                 0          NaN
# 1   019****  PROFESSOR 3 GRAU            6                 0          NaN
# 2   018****    Sem informação          NaN                -1         -1.0
# 3   018****  PROFESSOR 3 GRAU            6                 0          NaN
# 4   016****  PROFESSOR 3 GRAU            6                 0          NaN
#
#    NIVEL_CARGO SIGLA_FUNCAO  ...  DATA_NOMEACAO_CARGOFUNCAO  \
# 0            1           -1  ...                        NaN
# 1            1           -1  ...                        NaN
# 2           -1          FUC  ...                        NaN
# 3            1           -1  ...                        NaN
# 4            1           -1  ...                        NaN
#
#   DATA_INGRESSO_ORGAO  DOCUMENTO_INGRESSO_SERVICOPUBLICO  \
# 0          18/03/2011                              248.0
# 1          20/12/2011                              192.0
# 2          14/09/2010                              761.0
# 3          24/09/2010                              802.0
# 4          29/12/2008                             1002.0
#
#   DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO DIPLOMA_INGRESSO_CARGOFUNCAO  \
# 0                           11/04/2011                          NaN
# 1                           03/01/2012                          NaN
# 2                           18/10/2010                          NaN
# 3                           27/10/2010                          NaN
# 4                           09/02/2009                          NaN
#
#    DIPLOMA_INGRESSO_ORGAO DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO   ano  \
# 0                PORTARIA                        PORTARIA            -1  2013
# 1                PORTARIA                        PORTARIA            -1  2013
# 2                PORTARIA                        PORTARIA            -1  2013
# 3                PORTARIA                        PORTARIA            -1  2013
# 4                PORTARIA                        PORTARIA            -1  2013
#
#    mes
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#
# [5 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Id_SERVIDOR_PORTAL', 'NOME', 'CPF', 'MATRICULA', 'DESCRICAO_CARGO',
#        'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO',
#        'SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
#        'ATIVIDADE', 'OPCAO_PARCIAL', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
#        'COD_ORG_LOTACAO', 'ORG_LOTACAO', 'COD_ORGSUP_LOTACAO',
#        'ORGSUP_LOTACAO', 'COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
#        'COD_ORG_EXERCICIO', 'ORG_EXERCICIO', 'COD_ORGSUP_EXERCICIO',
#        'ORGSUP_EXERCICIO', 'COD_TIPO_VINCULO', 'TIPO_VINCULO',
#        'SITUACAO_VINCULO', 'DATA_INICIO_AFASTAMENTO',
#        'DATA_TERMINO_AFASTAMENTO', 'REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
#        'DATA_INGRESSO_CARGOFUNCAO', 'DATA_NOMEACAO_CARGOFUNCAO',
#        'DATA_INGRESSO_ORGAO', 'DOCUMENTO_INGRESSO_SERVICOPUBLICO',
#        'DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'DIPLOMA_INGRESSO_CARGOFUNCAO',
#        'DIPLOMA_INGRESSO_ORGAO', 'DIPLOMA_INGRESSO_SERVICOPUBLICO',
#        'UF_EXERCICIO', 'ano', 'mes'],
#       dtype='object')

# %%
df[['COD_TIPO_VINCULO', 'TIPO_VINCULO']]
# Out:
#       COD_TIPO_VINCULO TIPO_VINCULO
# 0                    2        Cargo
# 1                    2        Cargo
# 2                    1       Função
# 3                    2        Cargo
# 4                    2        Cargo
# ...                ...          ...
# 1088                 2        Cargo
# 1089                 2        Cargo
# 1090                 2        Cargo
# 1091                 2        Cargo
# 1092                 2        Cargo
#
# [1093 rows x 2 columns]

# %%
df_cargos = df[df['COD_TIPO_VINCULO']==2]

# %%
df_cargos.head(5)
# Out:
#    Id_SERVIDOR_PORTAL                           NOME             CPF  \
# 0            75714101      ADMA KATIA LACERDA CHAVES  ***.901.765-**
# 1            84412838  ADRIANA MIGLIORINI KIECKHOFER  ***.003.729-**
# 3            74814273  ALEXANDRE EMMANUEL BORTOLETTO  ***.202.949-**
# 4            81706863                   ALINE CRAIDE  ***.189.240-**
# 5            78919018           ALINE RIBEIRO PESSOA  ***.249.231-**
#
#   MATRICULA   DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  \
# 0   018****  PROFESSOR 3 GRAU            5                 0          NaN
# 1   019****  PROFESSOR 3 GRAU            6                 0          NaN
# 3   018****  PROFESSOR 3 GRAU            6                 0          NaN
# 4   016****  PROFESSOR 3 GRAU            6                 0          NaN
# 5   018****  PROFESSOR 3 GRAU            5                 0          NaN
#
#    NIVEL_CARGO SIGLA_FUNCAO  ...  DATA_NOMEACAO_CARGOFUNCAO  \
# 0            1           -1  ...                        NaN
# 1            1           -1  ...                        NaN
# 3            1           -1  ...                        NaN
# 4            1           -1  ...                        NaN
# 5            1           -1  ...                        NaN
#
#   DATA_INGRESSO_ORGAO  DOCUMENTO_INGRESSO_SERVICOPUBLICO  \
# 0          18/03/2011                              248.0
# 1          20/12/2011                              192.0
# 3          24/09/2010                              802.0
# 4          29/12/2008                             1002.0
# 5          07/10/2010                              932.0
#
#   DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO DIPLOMA_INGRESSO_CARGOFUNCAO  \
# 0                           11/04/2011                          NaN
# 1                           03/01/2012                          NaN
# 3                           27/10/2010                          NaN
# 4                           09/02/2009                          NaN
# 5                           27/10/2010                          NaN
#
#    DIPLOMA_INGRESSO_ORGAO DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO   ano  \
# 0                PORTARIA                        PORTARIA            -1  2013
# 1                PORTARIA                        PORTARIA            -1  2013
# 3                PORTARIA                        PORTARIA            -1  2013
# 4                PORTARIA                        PORTARIA            -1  2013
# 5                PORTARIA                        PORTARIA            -1  2013
#
#    mes
# 0    1
# 1    1
# 3    1
# 4    1
# 5    1
#
# [5 rows x 45 columns]

# %%
df_cargos.columns
# Out:
# Index(['Id_SERVIDOR_PORTAL', 'NOME', 'CPF', 'MATRICULA', 'DESCRICAO_CARGO',
#        'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO',
#        'SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
#        'ATIVIDADE', 'OPCAO_PARCIAL', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
#        'COD_ORG_LOTACAO', 'ORG_LOTACAO', 'COD_ORGSUP_LOTACAO',
#        'ORGSUP_LOTACAO', 'COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
#        'COD_ORG_EXERCICIO', 'ORG_EXERCICIO', 'COD_ORGSUP_EXERCICIO',
#        'ORGSUP_EXERCICIO', 'COD_TIPO_VINCULO', 'TIPO_VINCULO',
#        'SITUACAO_VINCULO', 'DATA_INICIO_AFASTAMENTO',
#        'DATA_TERMINO_AFASTAMENTO', 'REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
#        'DATA_INGRESSO_CARGOFUNCAO', 'DATA_NOMEACAO_CARGOFUNCAO',
#        'DATA_INGRESSO_ORGAO', 'DOCUMENTO_INGRESSO_SERVICOPUBLICO',
#        'DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'DIPLOMA_INGRESSO_CARGOFUNCAO',
#        'DIPLOMA_INGRESSO_ORGAO', 'DIPLOMA_INGRESSO_SERVICOPUBLICO',
#        'UF_EXERCICIO', 'ano', 'mes'],
#       dtype='object')

# %%
df_cargos = df_cargos[['Id_SERVIDOR_PORTAL', 'NOME', 'DESCRICAO_CARGO',
       'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
       'COD_ORG_LOTACAO', 'ORG_LOTACAO','COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
       'COD_ORG_EXERCICIO', 'ORG_EXERCICIO','SITUACAO_VINCULO','REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
       'DATA_INGRESSO_CARGOFUNCAO',
       'DATA_INGRESSO_ORGAO','DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'ano', 'mes']]

# %%
df_cargos[df['NOME']=='CLAUDIO ALEX DE OLIVEIRA PIRES']
# Out:
# /tmp/ipykernel_10679/1393212702.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cargos[df['NOME']=='CLAUDIO ALEX DE OLIVEIRA PIRES']
#      Id_SERVIDOR_PORTAL                            NOME  \
# 189            76121688  CLAUDIO ALEX DE OLIVEIRA PIRES
#
#                               DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO  \
# 189  PROFESSOR MAGISTERIO SUPERIOR-SUBSTITUTO            4                 0
#
#     PADRAO_CARGO  NIVEL_CARGO  COD_UORG_LOTACAO  \
# 189          NaN          401    26232000000732
#
#                                  UORG_LOTACAO  COD_ORG_LOTACAO  ...  \
# 189  UNIV FEDERAL DO OESTE DA BAHIA/UFOB/ICAD            26232  ...
#
#     COD_ORG_EXERCICIO                  ORG_EXERCICIO      SITUACAO_VINCULO  \
# 189             26232  Universidade Federal da Bahia  CONT.PROF.SUBSTITUTO
#
#          REGIME_JURIDICO JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 189  CONTRATO TEMPORARIO   20 HORAS SEMANAIS                18/06/2014
#
#     DATA_INGRESSO_ORGAO DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO   ano mes
# 189          31/07/2014                           18/06/2014  2014   7
#
# [1 rows x 23 columns]

# %%
df_funcao = df[df['COD_TIPO_VINCULO']==1]

# %%
df_funcao.columns
# Out:
# Index(['Id_SERVIDOR_PORTAL', 'NOME', 'CPF', 'MATRICULA', 'DESCRICAO_CARGO',
#        'CLASSE_CARGO', 'REFERENCIA_CARGO', 'PADRAO_CARGO', 'NIVEL_CARGO',
#        'SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
#        'ATIVIDADE', 'OPCAO_PARCIAL', 'COD_UORG_LOTACAO', 'UORG_LOTACAO',
#        'COD_ORG_LOTACAO', 'ORG_LOTACAO', 'COD_ORGSUP_LOTACAO',
#        'ORGSUP_LOTACAO', 'COD_UORG_EXERCICIO', 'UORG_EXERCICIO',
#        'COD_ORG_EXERCICIO', 'ORG_EXERCICIO', 'COD_ORGSUP_EXERCICIO',
#        'ORGSUP_EXERCICIO', 'COD_TIPO_VINCULO', 'TIPO_VINCULO',
#        'SITUACAO_VINCULO', 'DATA_INICIO_AFASTAMENTO',
#        'DATA_TERMINO_AFASTAMENTO', 'REGIME_JURIDICO', 'JORNADA_DE_TRABALHO',
#        'DATA_INGRESSO_CARGOFUNCAO', 'DATA_NOMEACAO_CARGOFUNCAO',
#        'DATA_INGRESSO_ORGAO', 'DOCUMENTO_INGRESSO_SERVICOPUBLICO',
#        'DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO', 'DIPLOMA_INGRESSO_CARGOFUNCAO',
#        'DIPLOMA_INGRESSO_ORGAO', 'DIPLOMA_INGRESSO_SERVICOPUBLICO',
#        'UF_EXERCICIO', 'ano', 'mes'],
#       dtype='object')

# %%
df_funcao[['Id_SERVIDOR_PORTAL', 'NOME','SIGLA_FUNCAO', 'NIVEL_FUNCAO', 'FUNCAO', 'CODIGO_ATIVIDADE',
       'ATIVIDADE', 'OPCAO_PARCIAL','DATA_INGRESSO_CARGOFUNCAO','ano', 'mes']]
# Out:
#        Id_SERVIDOR_PORTAL                         NOME SIGLA_FUNCAO  \
# 2                80626796           ALEX ALVAREZ SILVA          FUC
# 62               85611886            JAQUELINE FRITSCH           CD
# 63               85807316  JARINE BARBOZA ROCHA MENSCH           FG
# 166              75024781         BRUNO CASSEB PESSOTI          FUC
# 206              77820549   JACQUES ANTONIO DE MIRANDA           CD
# ...                   ...                          ...          ...
# 58223            76511331    RODRIGO DA PAIXAO ESTRELA           FG
# 58256            83018720    TAIDES TAVARES DOS SANTOS           FG
# 58268            84811125    TERESINHA MARIA MENEGAZZO           CD
# 58280            79524353   UILIAM RANGEL AMORIM SOUZA           CD
# 58291            78013924      VANESSA GODOY KINOSHITA           CD
#
#        NIVEL_FUNCAO                               FUNCAO  CODIGO_ATIVIDADE  \
# 2                 1  FUNCAO COMISSIONADA DE COORD. CURSO               220
# 62                4        CARGO DE  DIRECAO - CD - IFES                39
# 63                2            FUNCAO GRATIFICADA - IFES              2043
# 166               1  FUNCAO COMISSIONADA DE COORD. CURSO               220
# 206               3        CARGO DE  DIRECAO - CD - IFES                99
# ...             ...                                  ...               ...
# 58223             3            FUNCAO GRATIFICADA - IFES                56
# 58256             2            FUNCAO GRATIFICADA - IFES              3121
# 58268             4        CARGO DE  DIRECAO - CD - IFES                33
# 58280             4        CARGO DE  DIRECAO - CD - IFES                33
# 58291             2        CARGO DE  DIRECAO - CD - IFES               148
#
#                   ATIVIDADE OPCAO_PARCIAL DATA_INGRESSO_CARGOFUNCAO   ano  mes
# 2      COORDENADOR DE CURSO           NaN                01/10/2012  2013    1
# 62                  GERENTE             S                01/02/2009  2013    1
# 63                    CHEFE           NaN                01/11/2012  2013    1
# 166    COORDENADOR DE CURSO           NaN                29/11/2012  2013    2
# 206                 DIRETOR             S                31/10/2011  2013    2
# ...                     ...           ...                       ...   ...  ...
# 58223            ASSISTENTE           NaN                12/07/2022  2022   12
# 58256          VICE DIRETOR           NaN                13/10/2021  2022   12
# 58268           COORDENADOR             S                01/12/2021  2022   12
# 58280           COORDENADOR             S                01/11/2019  2022   12
# 58291            PRO-REITOR             S                01/10/2019  2022   12
#
# [6417 rows x 11 columns]
